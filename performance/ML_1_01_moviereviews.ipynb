# %%
performance = [{'Pos': 12500, 'Neg': 12500, 'TP': 10963, 'TN': 11019, 'FP': 1481, 'FN': 1537, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.87928, 'err': 0.12072000000000005, 'tpr': 0.87704, 'tnr': 0.88152, 'fpr': 0.11848, 'fnr': 0.12296, 'prec': 0.8809868209578914, 'name': 'neil'}, {'Pos': 12500, 'Neg': 12500, 'TP': 9477, 'TN': 10940, 'FP': 1560, 'FN': 3023, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.81668, 'err': 0.18332000000000004, 'tpr': 0.75816, 'tnr': 0.8752, 'fpr': 0.1248, 'fnr': 0.24184, 'prec': 0.8586572438162544, 'name': 'john'}, {'Pos': 12500, 'Neg': 12500, 'TP': 9624, 'TN': 11050, 'FP': 1450, 'FN': 2876, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.82696, 'err': 0.17303999999999997, 'tpr': 0.76992, 'tnr': 0.884, 'fpr': 0.116, 'fnr': 0.23008, 'prec': 0.8690626693155138, 'name': 'inhye'}, {'Pos': 12500, 'Neg': 12500, 'TP': 10074, 'TN': 10663, 'FP': 1837, 'FN': 2426, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.82948, 'err': 0.17052, 'tpr': 0.80592, 'tnr': 0.85304, 'fpr': 0.14696, 'fnr': 0.19408, 'prec': 0.8457728150449164, 'name': 'michael'}, {'Pos': 12500, 'Neg': 12500, 'TP': 9083, 'TN': 9431, 'FP': 3069, 'FN': 3417, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.74056, 'err': 0.25944, 'tpr': 0.72664, 'tnr': 0.75448, 'fpr': 0.24552, 'fnr': 0.27336, 'prec': 0.7474489795918368, 'name': 'soonk'}]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'ro')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

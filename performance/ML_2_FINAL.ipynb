# %%
performance = [{'Pos': 23, 'Neg': 1500, 'TP': 23, 'TN': 1498, 'FP': 2, 'FN': 0, 'pos': 0.015101772816808929, 'neg': 0.9848982271831911, 'clr': 0.015333333333333332, 'acc': 0.9986868023637557, 'err': 0.0013131976362442677, 'tpr': 1.0, 'tnr': 0.9986666666666667, 'fpr': 0.0013333333333333333, 'fnr': 0.0, 'prec': 0.92, 'name': 'j'}, {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1500, 'FP': 0, 'FN': 4, 'pos': 0.015101772816808929, 'neg': 0.9848982271831911, 'clr': 0.015333333333333332, 'acc': 0.9973736047275115, 'err': 0.0026263952724885353, 'tpr': 0.8260869565217391, 'tnr': 1.0, 'fpr': 0.0, 'fnr': 0.17391304347826086, 'prec': 1.0, 'name': 'soonk'}, {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1498, 'FP': 2, 'FN': 4, 'pos': 0.015101772816808929, 'neg': 0.9848982271831911, 'clr': 0.015333333333333332, 'acc': 0.9960604070912672, 'err': 0.003939592908732803, 'tpr': 0.8260869565217391, 'tnr': 0.9986666666666667, 'fpr': 0.0013333333333333333, 'fnr': 0.17391304347826086, 'prec': 0.9047619047619048, 'name': 'zinah'}, {'Pos': 23, 'Neg': 1500, 'TP': 20, 'TN': 1499, 'FP': 1, 'FN': 3, 'pos': 0.015101772816808929, 'neg': 0.9848982271831911, 'clr': 0.015333333333333332, 'acc': 0.9973736047275115, 'err': 0.0026263952724885353, 'tpr': 0.8695652173913043, 'tnr': 0.9993333333333333, 'fpr': 0.0006666666666666666, 'fnr': 0.13043478260869565, 'prec': 0.9523809523809523, 'name': 'sohee2'}, {'Pos': 23, 'Neg': 1500, 'TP': 23, 'TN': 1500, 'FP': 0, 'FN': 0, 'pos': 0.015101772816808929, 'neg': 0.9848982271831911, 'clr': 0.015333333333333332, 'acc': 1.0, 'err': 0.0, 'tpr': 1.0, 'tnr': 1.0, 'fpr': 0.0, 'fnr': 0.0, 'prec': 1.0, 'name': 'sohee3'}]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'go')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
# ## individual performance

# %%
plt.rcParams['figure.figsize'] = (10, 10)

# %%
for fit in performance:
    print(fit['name'].title() + ':')
    for fitt in performance:
        plt.plot(fitt['FP'] / fitt['Neg'], 
             fitt['TP'] / fitt['Pos'], 'o', color='0.75')
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], 'ro')
    plt.text(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['name'].title())
    plt.axis([0, 1, 0, 1])
    plt.title('ROC plot: test set')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.show()
    print('* * *')
# Out:
# J:
# * * *
# Soonk:
# * * *
# Zinah:
# * * *
# Sohee2:
# * * *
# Sohee3:
# * * *

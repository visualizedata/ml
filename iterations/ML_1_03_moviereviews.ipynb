# %%
performance = [{'Pos': 12500, 'Neg': 12500, 'TP': 10429, 'TN': 10792, 'FP': 1708, 'FN': 2071, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.84884, 'err': 0.15115999999999996, 'tpr': 0.83432, 'tnr': 0.86336, 'fpr': 0.13664, 'fnr': 0.16568, 'prec': 0.859273296531268, 'name': 'juwon'}, {'Pos': 12500, 'Neg': 12500, 'TP': 9885, 'TN': 10366, 'FP': 2134, 'FN': 2615, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.81004, 'err': 0.18996000000000002, 'tpr': 0.7908, 'tnr': 0.82928, 'fpr': 0.17072, 'fnr': 0.2092, 'prec': 0.8224477909975871, 'name': 'leo'}]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'ro')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

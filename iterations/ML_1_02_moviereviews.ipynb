# %%
performance = [{'Pos': 12500, 'Neg': 12500, 'TP': 10703, 'TN': 10111, 'FP': 2389, 'FN': 1797, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.83256, 'err': 0.16744000000000003, 'tpr': 0.85624, 'tnr': 0.80888, 'fpr': 0.19112, 'fnr': 0.14376, 'prec': 0.8175221509318668, 'name': 'wasim'}]
len(performance)
# Out:
# 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'ro')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

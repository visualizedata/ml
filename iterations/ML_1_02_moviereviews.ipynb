# %%
performance = [{'Pos': 12500, 'Neg': 12500, 'TP': 5596, 'TN': 12026, 'FP': 474, 'FN': 6904, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.70488, 'err': 0.29512000000000005, 'tpr': 0.44768, 'tnr': 0.96208, 'fpr': 0.03792, 'fnr': 0.55232, 'prec': 0.9219110378912685, 'name': 'asad'}, {'Pos': 12500, 'Neg': 12500, 'TP': 8746, 'TN': 9465, 'FP': 3035, 'FN': 3754, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.72844, 'err': 0.27156, 'tpr': 0.69968, 'tnr': 0.7572, 'fpr': 0.2428, 'fnr': 0.30032, 'prec': 0.7423818012053306, 'name': 'juwon'}, {'Pos': 12500, 'Neg': 12500, 'TP': 8616, 'TN': 9192, 'FP': 3308, 'FN': 3884, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.71232, 'err': 0.28768000000000005, 'tpr': 0.68928, 'tnr': 0.73536, 'fpr': 0.26464, 'fnr': 0.31072, 'prec': 0.7225763166722576, 'name': 'leo'}]
len(performance)
# Out:
# 3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'ro')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

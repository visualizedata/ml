# %%
performance_1 = [{'Pos': 12500, 'Neg': 12500, 'TP': 10131, 'TN': 10338, 'FP': 2162, 'FN': 2369, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.81876, 'err': 0.18123999999999996, 'tpr': 0.81048, 'tnr': 0.82704, 'fpr': 0.17296, 'fnr': 0.18952, 'prec': 0.8241275522655169, 'name': 'heew'}]
performance_2 = [{'Pos': 12500, 'Neg': 12500, 'TP': 10788, 'TN': 10798, 'FP': 1702, 'FN': 1712, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.86344, 'err': 0.13656000000000001, 'tpr': 0.86304, 'tnr': 0.86384, 'fpr': 0.13616, 'fnr': 0.13696, 'prec': 0.8637309847878303, 'name': 'heew'}]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance_1:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'bo')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
for fit in performance_2:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'ro')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
blue_patch = mpatches.Patch(color='blue', label='First iteration')
red_patch = mpatches.Patch(color='red', label='Second iteration')
plt.legend(handles=[blue_patch, red_patch])
plt.show()

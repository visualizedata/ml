# %%
performance_0 = [{'Pos': 12500, 'Neg': 12500, 'TP': 10069, 'TN': 10578, 'FP': 1922, 'FN': 2431, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.82588, 'err': 0.17412000000000005, 'tpr': 0.80552, 'tnr': 0.84624, 'fpr': 0.15376, 'fnr': 0.19448, 'prec': 0.8397131181719623, 'name': 'inhye'}, {'Pos': 12500, 'Neg': 12500, 'TP': 10086, 'TN': 10905, 'FP': 1595, 'FN': 2414, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.83964, 'err': 0.16035999999999995, 'tpr': 0.80688, 'tnr': 0.8724, 'fpr': 0.1276, 'fnr': 0.19312, 'prec': 0.8634534714493622, 'name': 'misha'}, {'Pos': 12500, 'Neg': 12500, 'TP': 10797, 'TN': 11007, 'FP': 1493, 'FN': 1703, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.87216, 'err': 0.12783999999999995, 'tpr': 0.86376, 'tnr': 0.88056, 'fpr': 0.11944, 'fnr': 0.13624, 'prec': 0.8785191212367779, 'name': 'neil'}, {'Pos': 12500, 'Neg': 12500, 'TP': 9212, 'TN': 9860, 'FP': 2640, 'FN': 3288, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.76288, 'err': 0.23712, 'tpr': 0.73696, 'tnr': 0.7888, 'fpr': 0.2112, 'fnr': 0.26304, 'prec': 0.7772527843401957, 'name': 'soonk'}]
performance_1 = [{'Pos': 12500, 'Neg': 12500, 'TP': 10131, 'TN': 10338, 'FP': 2162, 'FN': 2369, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.81876, 'err': 0.18123999999999996, 'tpr': 0.81048, 'tnr': 0.82704, 'fpr': 0.17296, 'fnr': 0.18952, 'prec': 0.8241275522655169, 'name': 'heew'}, {'Pos': 12500, 'Neg': 12500, 'TP': 4290, 'TN': 7739, 'FP': 4761, 'FN': 8210, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.48116, 'err': 0.51884, 'tpr': 0.3432, 'tnr': 0.61912, 'fpr': 0.38088, 'fnr': 0.6568, 'prec': 0.47398077560490554, 'name': 'shubhaya'}, {'Pos': 12500, 'Neg': 12500, 'TP': 10280, 'TN': 10600, 'FP': 1900, 'FN': 2220, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.8352, 'err': 0.16479999999999995, 'tpr': 0.8224, 'tnr': 0.848, 'fpr': 0.152, 'fnr': 0.1776, 'prec': 0.8440065681444991, 'name': 'james'}]
performance_2 = [{'Pos': 12500, 'Neg': 12500, 'TP': 10788, 'TN': 10798, 'FP': 1702, 'FN': 1712, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.86344, 'err': 0.13656000000000001, 'tpr': 0.86304, 'tnr': 0.86384, 'fpr': 0.13616, 'fnr': 0.13696, 'prec': 0.8637309847878303, 'name': 'heew'}, {'Pos': 12500, 'Neg': 12500, 'TP': 7435, 'TN': 8666, 'FP': 3834, 'FN': 5065, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.64404, 'err': 0.35596000000000005, 'tpr': 0.5948, 'tnr': 0.69328, 'fpr': 0.30672, 'fnr': 0.4052, 'prec': 0.659774602892892, 'name': 'shubhaya'}, {'Pos': 12500, 'Neg': 12500, 'TP': 10291, 'TN': 10618, 'FP': 1882, 'FN': 2209, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.83636, 'err': 0.16364, 'tpr': 0.82328, 'tnr': 0.84944, 'fpr': 0.15056, 'fnr': 0.17672, 'prec': 0.8453955475232071, 'name': 'james'}]
performance_3 = [{'Pos': 12500, 'Neg': 12500, 'TP': 10822, 'TN': 10833, 'FP': 1667, 'FN': 1678, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.8662, 'err': 0.13380000000000003, 'tpr': 0.86576, 'tnr': 0.86664, 'fpr': 0.13336, 'fnr': 0.13424, 'prec': 0.8665225398350549, 'name': 'heew'}, {'Pos': 12500, 'Neg': 12500, 'TP': 10235, 'TN': 10614, 'FP': 1886, 'FN': 2265, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.83396, 'err': 0.16603999999999997, 'tpr': 0.8188, 'tnr': 0.84912, 'fpr': 0.15088, 'fnr': 0.1812, 'prec': 0.8444022770398482, 'name': 'james'}]
performance_4 = [{'Pos': 12500, 'Neg': 12500, 'TP': 10671, 'TN': 10977, 'FP': 1523, 'FN': 1829, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.86592, 'err': 0.13407999999999998, 'tpr': 0.85368, 'tnr': 0.87816, 'fpr': 0.12184, 'fnr': 0.14632, 'prec': 0.8751025094308676, 'name': 'heew'}]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance_0:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'o', color='0.75')
for fit in performance_1:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'bo')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
for fit in performance_2:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'ro')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
for fit in performance_3:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'go')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
for fit in performance_4:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'yo')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
blue_patch = mpatches.Patch(color='blue', label='First iteration')
red_patch = mpatches.Patch(color='red', label='Second iteration')
green_patch = mpatches.Patch(color='green', label='Third iteration')
yellow_patch = mpatches.Patch(color='yellow', label='Fourth iteration')
plt.legend(handles=[blue_patch, red_patch, green_patch, yellow_patch])
plt.show()

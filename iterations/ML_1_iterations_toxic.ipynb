# %%
performance = [{'Pos': 6243, 'Neg': 57735, 'TP': 4560, 'TN': 51790, 'FP': 5945, 'FN': 1683, 'pos': 0.09758041826877989, 'neg': 0.90241958173122, 'clr': 0.10813198233307353, 'acc': 0.8807715152083528, 'err': 0.11922848479164716, 'tpr': 0.7304180682364247, 'tnr': 0.8970295314800381, 'fpr': 0.10297046851996189, 'fnr': 0.2695819317635752, 'prec': 0.43407900999524035, 'name': 'amina'}, {'Pos': 6243, 'Neg': 57735, 'TP': 3686, 'TN': 50403, 'FP': 7332, 'FN': 2557, 'pos': 0.09758041826877989, 'neg': 0.90241958173122, 'clr': 0.10813198233307353, 'acc': 0.8454312419894339, 'err': 0.15456875801056613, 'tpr': 0.5904212718244434, 'tnr': 0.8730059755780722, 'fpr': 0.12699402442192778, 'fnr': 0.40957872817555663, 'prec': 0.33454347431475767, 'name': 'geoff'}, {'Pos': 6243, 'Neg': 57735, 'TP': 3037, 'TN': 29630, 'FP': 28105, 'FN': 3206, 'pos': 0.09758041826877989, 'neg': 0.90241958173122, 'clr': 0.10813198233307353, 'acc': 0.5105973928537935, 'err': 0.48940260714620654, 'tpr': 0.4864648406214961, 'tnr': 0.5132068935654283, 'fpr': 0.48679310643457174, 'fnr': 0.5135351593785039, 'prec': 0.0975210326889731, 'name': 'isabel'}, {'Pos': 6243, 'Neg': 57735, 'TP': 4546, 'TN': 53803, 'FP': 3932, 'FN': 1697, 'pos': 0.09758041826877989, 'neg': 0.90241958173122, 'clr': 0.10813198233307353, 'acc': 0.9120166307168089, 'err': 0.08798336928319106, 'tpr': 0.7281755566234183, 'tnr': 0.9318957304927686, 'fpr': 0.06810426950723132, 'fnr': 0.2718244433765818, 'prec': 0.5362113706062751, 'name': 'jill'}]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'bo')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
blue_patch = mpatches.Patch(color='blue', label='First iteration')
# red_patch = mpatches.Patch(color='red', label='Second iteration')
plt.legend(handles=[blue_patch])
plt.show()

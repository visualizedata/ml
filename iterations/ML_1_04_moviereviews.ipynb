# %%
performance = [{'Pos': 12500, 'Neg': 12500, 'TP': 10526, 'TN': 10847, 'FP': 1653, 'FN': 1974, 'pos': 0.5, 'neg': 0.5, 'clr': 1.0, 'acc': 0.85492, 'err': 0.14508, 'tpr': 0.84208, 'tnr': 0.86776, 'fpr': 0.13224, 'fnr': 0.15792, 'prec': 0.8642745709828393, 'name': 'stephanie'}]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'ro')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

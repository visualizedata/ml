# %%
performance = [{'Pos': 23, 'Neg': 1500, 'TP': 20, 'TN': 1491, 'FP': 9, 'FN': 3, 'pos': 0.015101772816808929, 'neg': 0.9848982271831911, 'clr': 0.015333333333333332, 'acc': 0.9921208141825345, 'err': 0.007879185817465495, 'tpr': 0.8695652173913043, 'tnr': 0.994, 'fpr': 0.006, 'fnr': 0.13043478260869565, 'prec': 0.6896551724137931, 'name': '3_herson'}]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in performance:
    plt.plot(fit['fpr'], 
             fit['tpr'], 'ro')
    plt.text(fit['fpr'], 
             fit['tpr'], fit['name'].title())
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()
